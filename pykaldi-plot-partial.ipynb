# %% [markdown]
# Plotting experiments results
# ============================
#
# The first cell just parse the logs, so please continue to next cells with data and graphs.

# %%
import glob
from collections import namedtuple
# %pylab inline
#from pylab import *

exp_names = ['mono', 'tri1', 'tri2a', 'tri2b', 'tri2b_mmi', 'tri2b_mmi_b', 'tri2b_mpe']
Experiment = namedtuple('Experiment', exp_names)


def extractResults(f):
    every_n = int(f[-6:-4])
    with open(f, 'r') as r:
        lines = r.readlines()[1:]
        assert len(lines) == 2 * \
            len(exp_names), 'Log %s should contain all experiments for zerogram and bigram' % f
        build0 = []
        for exp, line in zip(exp_names, lines[:len(exp_names)]):
            assert exp in line, 'The line in log file should start with experiments name %s' % exp
            lm, lmw, wer, ser = line.split()[2:]
            assert lm == 'build0', 'First experiments should be tested on zerogram LM'
            build0.append(wer)
        build2 = []
        for exp, line in zip(exp_names, lines[len(exp_names):]):
            assert exp in line, 'The line in log file should start with experiments name %s' % exp
            lm, lmw, wer, ser = line.split()[2:]
            assert lm == 'build2', 'First experiments should be tested on bigram LM'
            build2.append(wer)
    # TODO init namedtuple  from list, TODO iterate over namedtuple properties
    # build0_exp = Experiment(build0[0], build0[1], build0[2], build0[3], build0[4], build0[5], build0[6])
    # build2_exp = Experiment(build2[0], build2[1], build2[2], build2[3], build2[4], build2[5], build2[6])
    return (every_n, build0, build2)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logs = glob.glob('data/*every*.log')
# TODO train data
train_data, partials = 2222, []
for f in logs:
    every_n, zerogram, bigram = extractResults(f)
    partials.append((train_data / every_n, zerogram, bigram))
partials.sort()
data_count = [ t for t, z, b in partials]
zerogram_exps = [ z for t, z, b in partials]
bigram_exps = [ b for t, z, b in partials]

# %% [markdown]
# Graphs
# ======

# %%
for i, exp in enumerate(exp_names):
    #print len(data_count), len(zerogram_exps[i]), '\n\n'        
    plot(data_count, [e[i] for e in zerogram_exps])
title('Zerogram experiments vs amount of training data')
print 'todo x descriptions %s' % str(exp_names)
savefig('partial-zerogram.ps', bbox_inches='tight')
# Out:
# todo x descriptions ['mono', 'tri1', 'tri2a', 'tri2b', 'tri2b_mmi', 'tri2b_mmi_b', 'tri2b_mpe']
# /usr/lib/python2.7/site-packages/matplotlib/tight_bbox.py:55: UserWarning: bbox_inches option for ps backend is not implemented yet.
#   "implemented yet." % (format))

# %%
for i, exp in enumerate(exp_names):
    #print len(data_count), len(zerogram_exps[i]), '\n\n'        
    plot(data_count, [e[i] for e in bigram_exps])
title('Bigram experiments vs amount of training data')
print 'todo x descriptions %s' % str(exp_names)
savefig('partial-bigram.ps', bbox_inches='tight')
# Out:
# todo x descriptions ['mono', 'tri1', 'tri2a', 'tri2b', 'tri2b_mmi', 'tri2b_mmi_b', 'tri2b_mpe']

# %% [markdown]
# Evaluation on Alex dialogue systems domain
# ------------------------------------------
#
# The domain is defined dialogue system handling dialogues about Czech public transport and wheather in Czech language.
#
# See http://ufal.ms.mff.cuni.cz/alex-dialogue-systems-framework/ptics for details.

# %%
data_portions = [ 0.05, 0.1, 0.2, 0.25, 0.3, 0.5, 0.7, 1.0}
shuffled_data = {25.37, 23.31, 20.58, 19.87, 19.58, 17.49, 15.76, 14.58}
noshuffled_data = {33.79, 32.44, 30.92, 30.19, 29.54, 28.41, 28.52, 25.59}
plot(data_portions, shuffled_data)
plot(data_portions, shuffled_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5d6c9f6d17a7> in <module>()
#       2 shuffled_data = {25.37, 23.31, 20.58, 19.87, 19.58, 17.49, 15.76, 14.58}
#       3 noshuffled_data = {33.79, 32.44, 30.92, 30.19, 29.54, 28.41, 28.52, 25.59}
# ----> 4 plot(data_portions, shuffled_data)
#       5 plot(data_portions, shuffled_data)
#
# /usr/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /usr/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4136
#    4137         for line in self._get_lines(*args, **kwargs):
# -> 4138             self.add_line(line)
#    4139             lines.append(line)
#    4140
#
# /usr/lib/python2.7/site-packages/matplotlib/axes.pyc in add_line(self, line)
#    1495             line.set_clip_path(self.patch)
#    1496
# -> 1497         self._update_line_limits(line)
#    1498         if not line.get_label():
#    1499             line.set_label('_line%d' % len(self.lines))
#
# /usr/lib/python2.7/site-packages/matplotlib/axes.pyc in _update_line_limits(self, line)
#    1506         Figures out the data limit of the given line, updating self.dataLim.
#    1507         """
# -> 1508         path = line.get_path()
#    1509         if path.vertices.size == 0:
#    1510             return
#
# /usr/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     741         """
#     742         if self._invalidy or self._invalidx:
# --> 743             self.recache()
#     744         return self._path
#     745
#
# /usr/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     418                 x = ma.asarray(xconv, np.float_)
#     419             else:
# --> 420                 x = np.asarray(xconv, np.float_)
#     421             x = x.ravel()
#     422         else:
#
# /usr/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     458
#     459     """
# --> 460     return array(a, dtype, copy=False, order=order)
#     461
#     462 def asanyarray(a, dtype=None, order=None):
#
# TypeError: float() argument must be a string or a number
